# %%
import numpy as np
from scipy.integrate import simps
import matplotlib.pyplot as plt
import pandas as pd
from math import sqrt,pow,log
import matplotlib.cm as cm
from scipy.integrate import quad
import h5py
from cobaya.run import run

# %%
data_PS = pd.read_excel (r'/root/Github_Repos/HubbleConstant-ConstraintsForVCG/pantheon_final.xlsx') 
z=data_PS.zcmb
amg=data_PS.mb
erramg=data_PS.dmb
label = {"Z_SN":z,"App_Mag":amg,"Error_App_Mag":erramg}
data_SN=pd.DataFrame(label)
sort_data_SN=data_SN.sort_values(by=['Z_SN'],ignore_index=True)
z=sort_data_SN.Z_SN
amg=sort_data_SN.App_Mag
erramg=sort_data_SN.Error_App_Mag
mu=amg + 19.35
errdm=erramg
label = {"Z_SN":z,"App_Mag":amg,"Error_App_Mag":erramg,"DMdata_SN": mu, "Error_DM_SN":errdm}
sort_data_SN=pd.DataFrame(label)
mu=sort_data_SN.DMdata_SN
cov_mat = pd.read_csv(r'/root/Github_Repos/HubbleConstant-ConstraintsForVCG/sys_full_long.txt')

# %%
cov_mat=pd.DataFrame(cov_mat).to_numpy()
cov_mat=cov_mat.reshape(1048,1048)

# %%
#omega_m, n , H0 SN
#number of samples 
sampl= 10000
#number of pars
par = 2

sigma=np.diag(cov_mat)
#assume the parameters have a gaussian distribution
sigma_omega= 0.01
sigma_n= 0.01
omega_b0 = 0.0000245
omega_r0=0.02

#Defining part which comes inside integeration of distance Luminosity

# inv_cov_mat= np.linalg.inv(cov_mat)
dmthSN= np.zeros(len(z))
dlthSN = np.zeros(len(z))
dldataSN=np.zeros(len(z))
error= np.zeros(len(z))
dlerror= np.zeros(len(z))

a=b=c=d=e=0
# DL theoretical from VCG model
def D_l(z,omega_m,n,h0):
    def int_func(x):
        return 1/(pow((1+x),2)*(omega_r0+(omega_b0/(1+x))+((1-omega_b0-omega_r0)*((omega_m*(1+x)**6)+(1-omega_m)*(1+z)**n)**(0.5)/(1+x)**(4)))**(0.5))
    g = quad(int_func,0,z)
    return (1+z)*g[0]*(3000/(h0))
#Function to calculate the value of mu_theory
def mu_theory(z,omega_m,n,h0):
        m=5*log(D_l(z,omega_m,n,h0),10)+25
        return m


# We now defile a likelihood function as given in the notes
# If the value comes out to be less than zero, set it to a very very small likelyhood
#Temporary variable to store mu(observation)- mu(theory)
dmu= np.empty(len(z))
def lnl(omega_m, n,h0):
        if(omega_m<=0.0 or h0<0):
            loglikely=-1.e100
        else:
            for i in range(len(z)):
                dmu[i]= mu[i]- mu_theory(z[i],omega_m,n,h0)
            loglikely= -0.5*np.sum(dmu**2/erramg**2)
        return loglikely

# %%
info_PS = {
    "likelihood": {
        "external": lnl},
    "params": dict([
        ("omega_m", {
            "prior": {"min": 0, "max": 1.3}, "ref": 0.1,
            "latex": r"\Omega_m"}),
        ("n", {
            "prior": {"min": -3, "max": 2.2}, "ref": 1.2,
            "latex": r"n"}),
        ("h0", {
            "prior": {"min": 0, "max": 1}, "ref": 0.7,
            "latex": r"h0"}) ]),
    "sampler": {
        "mcmc": {"Rminus1_stop": 0.01, 'max_tries':500}}}
updated_info_PS, sampler_PS = run(info_PS)
# Out:
# [external] Initialized external likelihood.
# [mcmc] Getting initial point... (this may take a few seconds)
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {external: 17.6}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: omega_m:0.1, n:1.2, h0:0.7
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-02-19 07:31:08 : 1 steps taken, and 0 accepted.
# [mcmc] Progress @ 2022-02-19 07:32:08 : 1660 steps taken, and 13 accepted.
# [mcmc] Progress @ 2022-02-19 07:33:08 : 3154 steps taken, and 22 accepted.
# <ipython-input-4-075cd25a8b1a>:27: RuntimeWarning: invalid value encountered in double_scalars
#   return 1/(pow((1+x),2)*(omega_r0+(omega_b0/(1+x))+((1-omega_b0-omega_r0)*((omega_m*(1+x)**6)+(1-omega_m)*(1+z)**n)**(0.5)/(1+x)**(4)))**(0.5))
# <ipython-input-4-075cd25a8b1a>:28: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   g = quad(int_func,0,z)
# [mcmc] Progress @ 2022-02-19 07:34:08 : 4764 steps taken, and 36 accepted.
# [mcmc] Progress @ 2022-02-19 07:35:08 : 6476 steps taken, and 53 accepted.
# [mcmc] Progress @ 2022-02-19 07:36:08 : 8521 steps taken, and 68 accepted.
# [mcmc] Progress @ 2022-02-19 07:37:08 : 10133 steps taken, and 79 accepted.
# [mcmc] Progress @ 2022-02-19 07:38:08 : 11706 steps taken, and 91 accepted.
# [mcmc] Progress @ 2022-02-19 07:39:08 : 13363 steps taken, and 99 accepted.
# [mcmc] Progress @ 2022-02-19 07:40:08 : 15149 steps taken, and 114 accepted.
# [mcmc] Learn + convergence test @ 120 samples accepted.
# [mcmc]  - Acceptance rate: 0.008
# [mcmc]  - Convergence of means: R-1 = 2.251422 after 96 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.018
# [mcmc]  - Convergence of means: R-1 = 0.952973 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 07:41:08 : 16517 steps taken, and 306 accepted.
# [mcmc] Learn + convergence test @ 360 samples accepted.
# [mcmc]  - Acceptance rate: 0.038
# [mcmc]  - Convergence of means: R-1 = 0.214642 after 288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.082
# [mcmc]  - Convergence of means: R-1 = 0.158126 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 07:42:08 : 17542 steps taken, and 588 accepted.
# [mcmc] Learn + convergence test @ 600 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.050228 after 480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.281
# [mcmc]  - Convergence of means: R-1 = 0.034115 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 840 samples accepted.
# [mcmc]  - Acceptance rate: 0.279
# [mcmc]  - Convergence of means: R-1 = 0.014271 after 672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 07:43:09 : 18625 steps taken, and 864 accepted.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.273
# [mcmc]  - Convergence of means: R-1 = 0.043337 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1080 samples accepted.
# [mcmc]  - Acceptance rate: 0.269
# [mcmc]  - Convergence of means: R-1 = 0.027699 after 864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 07:44:09 : 19720 steps taken, and 1170 accepted.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.275
# [mcmc]  - Convergence of means: R-1 = 0.053029 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1320 samples accepted.
# [mcmc]  - Acceptance rate: 0.275
# [mcmc]  - Convergence of means: R-1 = 0.017168 after 1056 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.274
# [mcmc]  - Convergence of means: R-1 = 0.016613 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 07:45:09 : 20796 steps taken, and 1478 accepted.
# [mcmc] Learn + convergence test @ 1560 samples accepted.
# [mcmc]  - Acceptance rate: 0.274
# [mcmc]  - Convergence of means: R-1 = 0.045913 after 1248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.276
# [mcmc]  - Convergence of means: R-1 = 0.015253 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1800 samples accepted.
# [mcmc]  - Acceptance rate: 0.277
# [mcmc]  - Convergence of means: R-1 = 0.009985 after 1440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 07:46:09 : 21877 steps taken, and 1800 accepted.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.277
# [mcmc]  - Convergence of means: R-1 = 0.012976 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2040 samples accepted.
# [mcmc]  - Acceptance rate: 0.275
# [mcmc]  - Convergence of means: R-1 = 0.017037 after 1632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 07:47:09 : 22938 steps taken, and 2086 accepted.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# [mcmc]  - Acceptance rate: 0.275
# [mcmc]  - Convergence of means: R-1 = 0.015558 after 1728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2280 samples accepted.
# [mcmc]  - Acceptance rate: 0.278
# [mcmc]  - Convergence of means: R-1 = 0.012010 after 1824 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 07:48:09 : 24005 steps taken, and 2398 accepted.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.278
# [mcmc]  - Convergence of means: R-1 = 0.011930 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2520 samples accepted.
# [mcmc]  - Acceptance rate: 0.277
# [mcmc]  - Convergence of means: R-1 = 0.010914 after 2016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2640 samples accepted.
# [mcmc]  - Acceptance rate: 0.276
# [mcmc]  - Convergence of means: R-1 = 0.011078 after 2112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 07:49:09 : 25111 steps taken, and 2697 accepted.
# [mcmc] Learn + convergence test @ 2760 samples accepted.
# [mcmc]  - Acceptance rate: 0.278
# [mcmc]  - Convergence of means: R-1 = 0.012871 after 2208 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [mcmc]  - Acceptance rate: 0.278
# [mcmc]  - Convergence of means: R-1 = 0.009941 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3000 samples accepted.
# [mcmc]  - Acceptance rate: 0.279
# [mcmc]  - Convergence of means: R-1 = 0.012105 after 2400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 07:50:09 : 26183 steps taken, and 3001 accepted.
# [mcmc] Learn + convergence test @ 3120 samples accepted.
# [mcmc]  - Acceptance rate: 0.280
# [mcmc]  - Convergence of means: R-1 = 0.017276 after 2496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3240 samples accepted.
# [mcmc]  - Acceptance rate: 0.279
# [mcmc]  - Convergence of means: R-1 = 0.010656 after 2592 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 07:51:09 : 27259 steps taken, and 3305 accepted.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [mcmc]  - Acceptance rate: 0.280
# [mcmc]  - Convergence of means: R-1 = 0.009378 after 2688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3480 samples accepted.
# [mcmc]  - Acceptance rate: 0.281
# [mcmc]  - Convergence of means: R-1 = 0.008818 after 2784 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.106974 after 3480 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 3480 accepted steps.

# %%
# Export the results to GetDist
from getdist.mcsamples import MCSamplesFromCobaya

gd_sample_PS = MCSamplesFromCobaya(updated_info_PS, sampler_PS.products()["sample"])
# Analyze and plot
mean_PS = gd_sample_PS.getMeans()[:3]
covmat_PS = gd_sample_PS.getCovMat().matrix[:3, :3]
print("Mean:")
print(mean_PS)
print("Covariance matrix:")
print(covmat_PS)



gd_sample_SN = MCSamplesFromCobaya(updated_info_SN, sampler_SN.products()["sample"])
# Analyze and plot
mean_SN = gd_sample_SN.getMeans()[:3]
covmat_SN = gd_sample_SN.getCovMat().matrix[:3, :3]
print("Mean:")
print(mean_SN)
print("Covariance matrix:")
print(covmat_SN)
import getdist.plots as gdplt

# gdplot_GW = gdplt.get_subplot_plotter()
# gdplot_GW.triangle_plot(gd_sample_GW, ["omega_m", "n", "h0"], filled=True)
gd_sample_GW = MCSamplesFromCobaya(updated_info_GW, sampler_GW.products()["sample"])
# Analyze and plot
mean_GW = gd_sample_GW.getMeans()[:3]
covmat_GW = gd_sample_GW.getCovMat().matrix[:3, :3]
print("Mean: ")
print(mean_GW)
print("Covariance matrix:")
print(covmat_GW)



g = gdplt.get_subplot_plotter()
g.settings.figure_legend_frame = False
g.settings.alpha_filled_add=0.4
g.settings.title_limit_fontsize = 14
g.triangle_plot([gd_sample_PS, gd_sample_SN, gd_sample_GW], ["omega_m", "n", "h0"], 
    filled=True, 
    legend_labels=['PS', 'SN', 'GW'], 
    legend_loc='upper right', 
    line_args=[{'lw':2,'ls':'--', 'color':'red'},
               {'lw':2, 'color':'darkblue'},
               {'lw':2, 'color':'green'}], 
    contour_colors=['red','darkblue','green'],
#     title_limit=1, # first title limit (for 1D plots) is 68% by default
#     markers={'h0':0}
               )
# Out:
# [root] *WARNING* outlier fraction 0.023563218390804597
# Mean:
# [0.11085099 0.3610803  0.70551638]
# Covariance matrix:
# [[ 9.66012340e-04 -8.39291960e-03  9.03265680e-05]
#  [-8.39291960e-03  8.30134537e-02 -1.06071409e-03]
#  [ 9.03265680e-05 -1.06071409e-03  1.93335187e-05]]
# [root] *WARNING* outlier fraction 0.05303030303030303
# Mean:
# [0.14083313 0.09144647 0.69625375]
# Covariance matrix:
# [[ 4.86175139e-03 -4.40311852e-02  8.95070373e-05]
#  [-4.40311852e-02  5.03532326e-01 -3.20681827e-03]
#  [ 8.95070373e-05 -3.20681827e-03  1.21732987e-04]]
# [root] *WARNING* outlier fraction 0.0005952380952380953
# Mean:
# [  0.47024946 -10.61896625   0.72195491]
# Covariance matrix:
# [[ 6.39563878e-02  1.03118535e-01 -1.72014210e-02]
#  [ 1.03118535e-01  6.46484180e+01 -3.33077326e-01]
#  [-1.72014210e-02 -3.33077326e-01  1.02306240e-02]]
# [root] *WARNING* 2D kernel density bandwidth optimizer failed for n, h0. Using fallback width: f(a) and f(b) must have different signs

# %%
# !wget http://supernova.lbl.gov/Union/figures/SCPUnion2.1_mu_vs_z.txt
d = np.genfromtxt('SCPUnion2.1_mu_vs_z.txt')
z1 = d.T[1]
mu1 = d.T[2]
errmu= d.T[3]
dlabel = 'SCP_2.1'
label = {"Z_SN":z1,"DMdata_SN":mu1,"Error_DM_SN":errmu}
data_SN=pd.DataFrame(label)
#print(data_SN)
sort_data_SN=data_SN.sort_values(by=['Z_SN'],ignore_index=True)
# !wget https://supernova.lbl.gov/Union/figures/SCPUnion2.1_covmat_sys.txt
cov_mat = np.genfromtxt('SCPUnion2.1_covmat_sys.txt')
z=sort_data_SN.Z_SN
mu=sort_data_SN.DMdata_SN
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2022-02-19 07:53:23--  https://supernova.lbl.gov/Union/figures/SCPUnion2.1_mu_vs_z.txt
# Resolving supernova.lbl.gov (supernova.lbl.gov)... 128.3.28.88
# Connecting to supernova.lbl.gov (supernova.lbl.gov)|128.3.28.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33899 (33K) [text/plain]
# Saving to: ‘SCPUnion2.1_mu_vs_z.txt.19’
#
# SCPUnion2.1_mu_vs_z 100%[===================>]  33.10K  83.3KB/s    in 0.4s
#
# 2022-02-19 07:53:25 (83.3 KB/s) - ‘SCPUnion2.1_mu_vs_z.txt.19’ saved [33899/33899]
#
# --2022-02-19 07:53:25--  https://supernova.lbl.gov/Union/figures/SCPUnion2.1_covmat_sys.txt
# Resolving supernova.lbl.gov (supernova.lbl.gov)... 128.3.28.88
# Connecting to supernova.lbl.gov (supernova.lbl.gov)|128.3.28.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6037238 (5.8M) [text/plain]
# Saving to: ‘SCPUnion2.1_covmat_sys.txt.14’
#
# SCPUnion2.1_covmat_ 100%[===================>]   5.76M   931KB/s    in 13s
#
# 2022-02-19 07:53:41 (458 KB/s) - ‘SCPUnion2.1_covmat_sys.txt.14’ saved [6037238/6037238]

# %%
#omega_m, n , H0 SN
#number of samples 
sampl= 10000
#number of pars
par = 2


#assume the parameters have a gaussian distribution
sigma_omega= 0.01
sigma_n= 0.01
omega_b0 = 0.0000245
omega_r0=0.02

#Defining part which comes inside integeration of distance Luminosity

inv_cov_mat= np.linalg.inv(cov_mat)
dmthSN= np.zeros(len(z))
dlthSN = np.zeros(len(z))
dldataSN=np.zeros(len(z))
error= np.zeros(len(z))
dlerror= np.zeros(len(z))

a=b=c=d=e=0
# DL theoretical from VCG model
def D_l(z,omega_m,n,h0):
    def int_func(x):
        return 1/(pow((1+x),2)*(omega_r0+(omega_b0/(1+x))+((1-omega_b0-omega_r0)*((omega_m*(1+x)**6)+(1-omega_m)*(1+z)**n)**(0.5)/(1+x)**(4)))**(0.5))
    g = quad(int_func,0,z)
    return (1+z)*g[0]*(3000/(h0))
#Function to calculate the value of mu_theory
def mu_theory(z,omega_m,n,h0):
        m=5*log(D_l(z,omega_m,n,h0),10)+25
        return m


# We now defile a likelihood function as given in the notes
# If the value comes out to be less than zero, set it to a very very small likelyhood
#Temporary variable to store mu(observation)- mu(theory)
dmu= np.empty(len(z))
def lnl(omega_m, n,h0):
        if(omega_m<=0.0 or h0<0):
            loglikely=-1.e100
        else:
            for i in range(len(z)):
                dmu[i]= mu[i]- mu_theory(z[i],omega_m,n,h0)
            loglikely= -0.5*np.dot(dmu,np.dot(inv_cov_mat,dmu))
        return loglikely

# %%
info_SN = {
    "likelihood": {
        "external": lnl},
    "params": dict([
        ("omega_m", {
            "prior": {"min": 0, "max": 1.3},
            "latex": r"\Omega_m"}),
        ("n", {
            "prior": {"min": -3, "max": 2.2},
            "latex": r"n"}),
        ("h0", {
            "prior": {"min": 0, "max": 1},
            "latex": r"h0"}) ]),
    "sampler": {
        "mcmc": {"Rminus1_stop": 0.05, 'max_tries':500}}}

# %%
updated_info_SN, sampler_SN = run(info_SN)
# Out:
# [external] Initialized external likelihood.
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {external: 22.5}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: omega_m:0.0305703, n:-2.39855, h0:0.7402615
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-02-19 07:54:11 : 1 steps taken, and 0 accepted.
# [mcmc] Progress @ 2022-02-19 07:55:12 : 2709 steps taken, and 76 accepted.
# [mcmc] Learn + convergence test @ 120 samples accepted.
# [mcmc]  - Acceptance rate: 0.029
# [mcmc]  - Convergence of means: R-1 = 5.567107 after 96 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.069
# [mcmc]  - Convergence of means: R-1 = 2.565974 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 360 samples accepted.
# [mcmc]  - Acceptance rate: 0.126
# [mcmc]  - Convergence of means: R-1 = 0.478480 after 288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 07:56:12 : 4895 steps taken, and 362 accepted.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.205
# [mcmc]  - Convergence of means: R-1 = 1.174082 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 600 samples accepted.
# [mcmc]  - Acceptance rate: 0.310
# [mcmc]  - Convergence of means: R-1 = 0.052730 after 480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.082431 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 07:57:12 : 6564 steps taken, and 833 accepted.
# [mcmc] Learn + convergence test @ 840 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.057569 after 672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.290
# [mcmc]  - Convergence of means: R-1 = 0.042167 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1080 samples accepted.
# [mcmc]  - Acceptance rate: 0.283
# [mcmc]  - Convergence of means: R-1 = 0.050460 after 864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.282
# [mcmc]  - Convergence of means: R-1 = 0.018978 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1320 samples accepted.
# [mcmc]  - Acceptance rate: 0.283
# [mcmc]  - Convergence of means: R-1 = 0.024249 after 1056 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.079389 after 1320 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 1320 accepted steps.

# %%
name=np.array(['GW190521','GW190706_222641','GW190413_134308','GW190514_065416','GW190719_215514','GW190521',"GW190909_114149","GW190413_052954",'GW190803_022701','GW190731_140936','GW190727_060333','GW190620_030421','GW190421_213856','GW170729','GW190602_175927','GW190527_092055','GW190519_153544','GW190424_180648','GW190929_012149','GW190828_063405','GW190701_203306','GW190513_205428','GW170823','GW190517_055101','GW190915_235702','GW190828_065509','GW190408_181802','GW190910_112807','GW190512_180714','GW190503_185404','GW190521_074359','GW170818','GW151012','GW170809','GW170104','GW190728_064510','GW190708_232457','GW190630_185205','GW190720_000836','GW190707_093326','GW190930_133541','GW190412','GW190924_021846','GW170814','GW151226','GW150914','GW190426_152155','GW200115_042309','GW170608','GW200105_162426','GW190814','GW190425','GW170817'])
full_DL_GW=np.array([[5300.0,2400,-2600],[4420.0,2590,-1930],[4450,2480,-2120],[4130.0,2650,-2170],[3940.0,2590,-2000],[3920.0,2190,-1950],[3770.0,3270,-2220],[3550.0,2270,-1660],[3270.0,1950,-1580],[3300.0,2390,-1720],[3300.0,1540,-1500],[2810.0,1680,-1310],[2880.0,1370,-1380],[2840.0,1400,-1360],[2690.0,1790,-1120],[2490.0,2480,-1240],[2530.0,1830,-920],[2200.0,1580,-1160],[2130.0,3650,-1050],[2130.0,660,-930],[2060.0,760,-730],[2060.0,880,-800],[1940.0,970,-900],[1860.0,1620,-840],[1620.0,710,-610],[1600.0,620,-600],[1550.0,400,-600],[1460.0,1030,-580],[1430.0,550,-550],[1450.0,690,-630],[1240.0,400,-570],[1060.0,420,-380],[1080.0,550,-490],[1030.0,320,-390],[990.0,440,-430],[870.0,260,-370],[880.0,330,-390],[890.0,560,-370],[790.0,690,-320],[770.0,380,-370],[760.0,360,-320],[740.0,140,-170],[570.0,220,-220],[600.0,150,-220],[450.0,180,-190],[440.0,150,-170],[370.0,180,-160],[300.0,150,-100],[320.0,120,-110],[280.0,110,-110],[241.0,41,-45],[159.0,69,-72],[40.0,7,-15]])
full_Z_GW=np.array([[0.82,0.28,-0.34],[0.71,0.32,-0.27],[0.71,0.31,-0.30],[0.67,0.33,-0.31],[0.64,0.33,-0.29],[0.64,0.28,-0.28],[0.62,0.41,-0.33],[0.59,0.29,-0.24],[0.55,0.26,-0.24],[0.55,0.31,-0.26],[0.55,0.21,-0.22],[0.49,0.23,-0.20],[0.49,0.19,-0.21],[0.49,0.19,-0.21],[0.47,0.25,-0.17],[0.44,0.34,-0.20],[0.44,0.25,-0.14],[0.39,0.23,-0.19],[0.38,0.49,-0.17],[0.38,0.10,-0.15],[0.37,0.11,-0.12],[0.37,0.13,-0.13],[0.35,0.15,-0.15],[0.34,0.24,-0.14],[0.3,0.11,-0.10],[0.3,0.10,-0.10],[0.29,0.06,-0.10],[0.28,0.16,-0.10],[0.27,0.09,-0.10],[0.27,0.11,-0.11],[0.24,0.07,-0.10],[0.21,0.07,-0.07],[0.21,0.09,-0.09],[0.2,0.05,-0.07],[0.2,0.08,-0.08],[0.18,0.05,-0.07],[0.18,0.06,-0.07],[0.18,0.10,-0.07],[0.16,0.12,-0.06],[0.16,0.07,-0.07],[0.15,0.06,-0.06],[0.15,0.03,-0.03],[0.12,0.04,-0.04],[0.12,0.03,-0.04],[0.09,0.04,-0.04],[0.09,0.03,-0.03],[0.08,0.04,-0.03],[0.07,0.03,-0.02],[0.07,0.02,-0.02],[0.06,0.02,-0.02],[0.053,0.009,-0.010],[0.04,0.01,-0.02],[0.01,0.00,-0.00]])
# Number of events
a=name.size

#Defining arrays
dldata_GW=np.zeros(a)
dlUP=np.zeros(a)
dlLOW=np.zeros(a)
dlTOP=np.zeros(a)
dlBOTTOM=np.zeros(a)
dmtop=np.zeros(a)
dmbottom=np.zeros(a)
Z_GW=np.zeros(a)
dmth_GW=np.zeros(a)
dmdata_GW=np.zeros(a)
dlth_GW = np.zeros(a)
dmtoperr=np.zeros(a)
dmbottomerr=np.zeros(a)
#defining variables for index of the above arrays
b=c=d=e=f=h=k=l=m=x=y=p=q=r=s=0
#extracting redshifts and DL from the full data
for i in full_Z_GW:
  Z_GW[e]+=i[0]
  e+=1
for i in full_DL_GW:
  dldata_GW[b]+=i[0]
  b+=1
for i in dldata_GW:
  dmdata_GW[h]+=5*log(i,10)+25
  h+=1
for i in full_DL_GW:
  dlUP[c]+=i[0]+i[1]
  c+=1
for i in full_DL_GW:
  dlLOW[d]+=i[0]+i[2]
  d+=1
label1 = {"Event_Name":name,"Z_GW":Z_GW,"dLdata_GW":dldata_GW,"DMdata_GW": dmdata_GW,"DL_Uplimit": dlUP, "DL_Lowlimit": dlLOW}
data_GW=pd.DataFrame(label1)
data_GWTC3 = pd.read_excel (r'/root/Github_Repos/VCG_GW/oldGW.xlsx')
data_GWTC3.index= np.arange(53,88)

mucollect=[data_GW.Z_GW,data_GWTC3.redshift]
z1 = pd.concat(mucollect)

namecollect=[data_GW.Event_Name,data_GWTC3.Event_Name_GWTC3]
finalevents = pd.concat(namecollect)

dlcollect=[data_GW.dLdata_GW,data_GWTC3.luminosity_distance]
finaldl1 = pd.concat(dlcollect)

dlupcollect=[data_GW.DL_Uplimit,data_GWTC3.luminosity_distance_upper]
finaldlup1 = pd.concat(dlupcollect)

dllowcollect=[data_GW.DL_Lowlimit,data_GWTC3.luminosity_distance_lower]
finaldllow1 = pd.concat(dllowcollect)
label2 = {"EventName":finalevents,"ZGW":z1,"dLdataGW":finaldl1,"DLUplimit":finaldlup1,"DLLowlimit":finaldllow1}
Final_GW=pd.DataFrame(label2)
sort_data_GW=Final_GW.sort_values(by=['ZGW'],ignore_index=True)

z=sort_data_GW.ZGW
finaldl=sort_data_GW.dLdataGW
finaldlup=sort_data_GW.DLUplimit
finaldllow=sort_data_GW.DLLowlimit
a=finalevents.size

#Defining arrays
dlTOP=np.zeros(a)
dlBOTTOM=np.zeros(a)
dmtop=np.zeros(a)
dmbottom=np.zeros(a)
dmth3_GW=np.zeros(a)
mu=np.zeros(a)
dlth3_GW = np.zeros(a)
dmtoperr=np.zeros(a)
dmbottomerr=np.zeros(a)
#defining variables for index of the above arrays
f=h=k=l=m=x=y=p=q=r=s=0

for i in finaldl:
  mu[h]+=5*log(i,10)+25
  h+=1
for i in finaldlup:
  dmtop[f]+=5*log(i,10)+25
  f+=1
for i in finaldllow:
  dmbottom[k]+=5*log(i,10)+25
  k+=1
#upper and lower differences for errors
for (i,j) in zip(mu,dmtop):
  dmtoperr[r]+=j-i
  r+=1
for (i,j) in zip(mu,dmbottom):
  dmbottomerr[s]+=i-j
  s+=1

# %%
#number of samples 
sampl= 10000
#number of pars
par = 2

sigma=(dmtoperr+dmbottomerr)/2
#assume the parameters have a gaussian distribution
sigma_omega= 0.01
sigma_n= 0.01
omega_b0 = 0.0000245
omega_r0=0.02


#Defining part which comes inside integeration of distance Luminosity


dmthSN= np.zeros(len(z))
dlthSN = np.zeros(len(z))
dldataSN=np.zeros(len(z))
error= np.zeros(len(z))
dlerror= np.zeros(len(z))

a=b=c=d=e=0
# DL theoretical from VCG model
def D_l(z,omega_m,n,h0):
    def int_func(x):
        return 1/(pow((1+x),2)*(omega_r0+(omega_b0/(1+x))+((1-omega_b0-omega_r0)*((omega_m*(1+x)**6)+(1-omega_m)*(1+z)**n)**(0.5)/(1+x)**(4)))**(0.5))
    g = quad(int_func,0,z)
    return (1+z)*g[0]*(3000/(h0))
#Function to calculate the value of mu_theory
def mu_theory(z,omega_m,n,h0):
        m=5*log(D_l(z,omega_m,n,h0),10)+25
        return m

# We now defile a likelihood function as given in the notes
# If the value comes out to be less than zero, set it to a very very small likelyhood
#Temporary variable to store mu(observation)- mu(theory)
dmu= np.empty(len(z))
def lnl(omega_m, n,h0):
        if(omega_m<=0.0 or omega_m>=1 or h0<0):
            loglikely=-1.e100
        else:
            for i in range(len(z)):
                dmu[i]= mu[i]- mu_theory(z[i],omega_m,n,h0)
            loglikely= -0.5*np.sum(dmu**2/sigma**2)
        return loglikely

# %%
info_GW = {
    "likelihood": {
        "external": lnl},
    "params": dict([
        ("omega_m", {
            "prior": {"min": 0, "max": 2.5},
            "latex": r"\Omega_m"}),
        ("n", {
            "prior": {"min": -25, "max": 4},
            "latex": r"n"}),
        ("h0", {
            "prior": {"min": 0, "max": 2},
            "latex": r"h0"}) ]),
    "sampler": {
        "mcmc": {"Rminus1_stop": 0.01, 'max_tries':10000}}}

updated_info_GW, sampler_GW = run(info_GW)
# Out:
# [external] Initialized external likelihood.
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {external: 72900.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: omega_m:1.938112, n:-18.91695, h0:0.7082776
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-02-19 08:07:34 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 120 samples accepted.
# [mcmc]  - Acceptance rate: 0.078
# [mcmc]  - Convergence of means: R-1 = 3.113856 after 96 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.142
# [mcmc]  - Convergence of means: R-1 = 0.669919 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 360 samples accepted.
# [mcmc]  - Acceptance rate: 0.189
# [mcmc]  - Convergence of means: R-1 = 0.413763 after 288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.226
# [mcmc]  - Convergence of means: R-1 = 0.219294 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 600 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.132026 after 480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.241
# [mcmc]  - Convergence of means: R-1 = 0.051060 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 840 samples accepted.
# [mcmc]  - Acceptance rate: 0.235
# [mcmc]  - Convergence of means: R-1 = 0.065267 after 672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.233
# [mcmc]  - Convergence of means: R-1 = 0.037299 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1080 samples accepted.
# [mcmc]  - Acceptance rate: 0.233
# [mcmc]  - Convergence of means: R-1 = 0.043718 after 864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.234
# [mcmc]  - Convergence of means: R-1 = 0.024441 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1320 samples accepted.
# [mcmc]  - Acceptance rate: 0.232
# [mcmc]  - Convergence of means: R-1 = 0.041136 after 1056 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.231
# [mcmc]  - Convergence of means: R-1 = 0.042155 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1560 samples accepted.
# [mcmc]  - Acceptance rate: 0.231
# [mcmc]  - Convergence of means: R-1 = 0.068561 after 1248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.232
# [mcmc]  - Convergence of means: R-1 = 0.028015 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1800 samples accepted.
# [mcmc]  - Acceptance rate: 0.231
# [mcmc]  - Convergence of means: R-1 = 0.025536 after 1440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.229
# [mcmc]  - Convergence of means: R-1 = 0.023928 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2040 samples accepted.
# [mcmc]  - Acceptance rate: 0.226
# [mcmc]  - Convergence of means: R-1 = 0.021219 after 1632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# [mcmc]  - Acceptance rate: 0.226
# [mcmc]  - Convergence of means: R-1 = 0.018110 after 1728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2280 samples accepted.
# [mcmc]  - Acceptance rate: 0.225
# [mcmc]  - Convergence of means: R-1 = 0.023527 after 1824 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.227
# [mcmc]  - Convergence of means: R-1 = 0.012415 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2520 samples accepted.
# [mcmc]  - Acceptance rate: 0.226
# [mcmc]  - Convergence of means: R-1 = 0.019798 after 2016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2640 samples accepted.
# [mcmc]  - Acceptance rate: 0.226
# [mcmc]  - Convergence of means: R-1 = 0.020058 after 2112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2760 samples accepted.
# [mcmc]  - Acceptance rate: 0.227
# [mcmc]  - Convergence of means: R-1 = 0.014277 after 2208 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [mcmc]  - Acceptance rate: 0.225
# [mcmc]  - Convergence of means: R-1 = 0.015064 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3000 samples accepted.
# [mcmc]  - Acceptance rate: 0.225
# [mcmc]  - Convergence of means: R-1 = 0.028504 after 2400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3120 samples accepted.
# [mcmc]  - Acceptance rate: 0.226
# [mcmc]  - Convergence of means: R-1 = 0.019374 after 2496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3240 samples accepted.
# [mcmc]  - Acceptance rate: 0.226
# [mcmc]  - Convergence of means: R-1 = 0.014289 after 2592 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [mcmc]  - Acceptance rate: 0.227
# [mcmc]  - Convergence of means: R-1 = 0.015436 after 2688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3480 samples accepted.
# [mcmc]  - Acceptance rate: 0.226
# [mcmc]  - Convergence of means: R-1 = 0.021331 after 2784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3600 samples accepted.
# [mcmc]  - Acceptance rate: 0.226
# [mcmc]  - Convergence of means: R-1 = 0.018313 after 2880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3720 samples accepted.
# [mcmc]  - Acceptance rate: 0.225
# [mcmc]  - Convergence of means: R-1 = 0.018402 after 2976 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3840 samples accepted.
# [mcmc]  - Acceptance rate: 0.224
# [mcmc]  - Convergence of means: R-1 = 0.021623 after 3072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3960 samples accepted.
# [mcmc]  - Acceptance rate: 0.224
# [mcmc]  - Convergence of means: R-1 = 0.022275 after 3168 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4080 samples accepted.
# [mcmc]  - Acceptance rate: 0.224
# [mcmc]  - Convergence of means: R-1 = 0.019259 after 3264 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4200 samples accepted.
# [mcmc]  - Acceptance rate: 0.222
# [mcmc]  - Convergence of means: R-1 = 0.013395 after 3360 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4320 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.018114 after 3456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4440 samples accepted.
# [mcmc]  - Acceptance rate: 0.222
# [mcmc]  - Convergence of means: R-1 = 0.018346 after 3552 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4560 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.025245 after 3648 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2022-02-19 08:08:34 : 21735 steps taken, and 4659 accepted.
# [mcmc] Learn + convergence test @ 4680 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.013434 after 3744 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4800 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.012380 after 3840 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4920 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.006480 after 3936 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5040 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.008939 after 4032 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.044925 after 5040 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 5040 accepted steps.
