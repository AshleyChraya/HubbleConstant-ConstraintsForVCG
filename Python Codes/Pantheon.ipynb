# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.integrate import quad
from math import sqrt,pow,log
import pandas as pd
from matplotlib.pyplot import figure
plt.rcParams["figure.figsize"] = (20,14)
# plt.style.use('/mnt/49258d32-6ae7-47af-b8e9-cd883888e8b3/github/HubbleConstant-ConstraintsForVCG/standard.mplstyle')

# %%
data_PS = pd.read_excel('/media/ash/1tb/github/HubbleConstant-ConstraintsForVCG/pantheon_final.xlsx') 
data_PS.head()
# Out:
#     #name     zcmb      zhel        mb      dmb
# 0  03D1au  0.50349  0.504299  22.93445  0.12605
# 1  03D1ax  0.49520  0.496005  22.88020  0.11765
# 2  03D1co  0.67820  0.678997  24.03770  0.20560
# 3  03D1ew  0.86720  0.868006  24.34685  0.17385
# 4  03D1fq  0.79920  0.799997  24.36050  0.17435

# %%
data_PS.columns
# Out:
# Index(['#name', 'zcmb', 'zhel', 'mb', 'dmb'], dtype='object')

# %%
z=data_PS.zcmb # Redshift
amg=data_PS.mb #Apparent magnitude
erramg=data_PS.dmb #error in Apparent magnitude
label = {"Z_SN":z,"App_Mag":amg,"Error_App_Mag":erramg}
data_SN=pd.DataFrame(label)
data_SN.head()
# Out:
#       Z_SN   App_Mag  Error_App_Mag
# 0  0.50349  22.93445        0.12605
# 1  0.49520  22.88020        0.11765
# 2  0.67820  24.03770        0.20560
# 3  0.86720  24.34685        0.17385
# 4  0.79920  24.36050        0.17435

# %%
sort_data_SN=data_SN.sort_values(by=['Z_SN'],ignore_index=True)
sort_data_SN.head()
# Out:
#       Z_SN   App_Mag  Error_App_Mag
# 0  0.01012  13.90745        0.19825
# 1  0.01038  14.04960        0.20480
# 2  0.01043  13.92480        0.20035
# 3  0.01082  14.00860        0.18445
# 4  0.01209  13.97910        0.19140

# %%
z=sort_data_SN.Z_SN #Redshift
amg=sort_data_SN.App_Mag  #Apparent Magnitude
erramg=sort_data_SN.Error_App_Mag  #Error in apparent magnitude
mu=amg + 19.35 #Distance modulus # m - M = -5 + 5 log (d) where d is in pc
errdm=erramg
label = {
    "Z_SN":z,"App_Mag":amg,"Error_App_Mag":erramg,"DMdata_SN": mu,"Error_DM_SN":errdm
}
sort_data_SN=pd.DataFrame(label)
mu=sort_data_SN.DMdata_SN

# %%
sort_data_SN.head()
# Out:
#       Z_SN   App_Mag  Error_App_Mag  DMdata_SN  Error_DM_SN
# 0  0.01012  13.90745        0.19825   33.25745      0.19825
# 1  0.01038  14.04960        0.20480   33.39960      0.20480
# 2  0.01043  13.92480        0.20035   33.27480      0.20035
# 3  0.01082  14.00860        0.18445   33.35860      0.18445
# 4  0.01209  13.97910        0.19140   33.32910      0.19140

# %%
sort_data_SN.shape
# Out:
# (1048, 5)

# %% [markdown]
# PARAMETER Definition (Hubble Parameter, Energy density of Radiation (r0) and Baryonic Matter (b0), in the current epoch)

# %%
omega_r0=0.0000245 #Radiation
omega_b0=0.02 #Baryonic matter
H0=69.8 #Hubble constant in (Km/s)/Mpc

# %% [markdown]
# Defining the function to find luminosity distance and followed by calculating the luminosity distance through integration by quad function of the scipy module for different combination of Omega M and n and from that the distance modulus.

# %% [markdown]
# Friedmann equation: $H^2=\Omega_{ch0} H_0^2 (1+z)^4 X^2(z)$ where $X^{2}(z)=\frac{\Omega_{r 0}}{1-\Omega_{r 0}-\Omega_{b 0}}+\frac{\Omega_{b 0} }{1-\Omega_{r 0}-\Omega_{\theta 0}(1+z)}+\frac{\left(\Omega_{m}(1+z)^6+(1-\Omega_{m})(1+z)^n\right)^{1 / 2}}{(1+z)^4}$

# %% [markdown]
# Calculating the luminosity distance by $d_l = \frac{c(1+z)}{H0} \int_{0}^{z} \frac{dz}{(1+z)^2X(z)}$

# %%
def int_func(redshift):
      return 1/((pow((1+redshift),2)*(omega_r0+(omega_b0/(1+redshift))
      +((1-omega_b0-omega_r0)*((omega_m*(1+redshift)**6)
      +(1-omega_m)*(1+redshift)**n)**(0.5)/(1+redshift)**(4)))**(0.5)))

# %%
dmthSN, dlthSN, dldataSN, error, dlerror  = (
    np.zeros(len(z)), np.zeros(len(z)), np.zeros(len(z)),np.zeros(len(z)), np.zeros(len(z)))
# From minimization of chi square
omega_m=0.09
n=1.4545
c=3*10**5 #Km/s
# DL theoretical from VCG model
for a,redshift in zip(sort_data_SN.index,sort_data_SN.Z_SN):
  g = quad(int_func,0,redshift)
  dlthSN[a]+=(1+redshift)*g[0]*(c/(H0)) # g[0] because g[1] gives absolute error in the result obtained
# DM from DL theoretical model VCG
for a,i in zip(sort_data_SN.index,dlthSN):
  dmthSN[a]+=5*log(i,10)+25 #m-M=mu=5log(dl/dl,0) where M is the magnitude of the 
#standard candle at some nearby distance dL,0.n the conventional definition of the 
#distance modulus, dL,0 = 10 pc and M at this distance is usually referred to as the
#absolute magnitude. Converting dl,0 in Mpc, we get mu=5log(dl) + 25

# Distance luminosity from data in Mpc
for a,i in zip(sort_data_SN.index,sort_data_SN.DMdata_SN):
  dldataSN[a]+=10**((i/5)+1)/10**6
#10**((i/5)+1) will give in dl in pc or 10**((i/5)-5) in Mpc
# Calculating error bars of DL
for (a,i,j) in zip(sort_data_SN.index,mu,errdm):   
  error[a]+= 10**((i+j)/5+1)/10**6
for (a,i,j) in zip(sort_data_SN.index,dldataSN,error):
    dlerror[a]+=j-i   #Error in data distance luminosity
sort_data_SN["DMth_SN"]=dmthSN
sort_data_SN["dLth_SN"] = dlthSN
sort_data_SN["dLdata_SN"] = dldataSN
sort_data_SN["Error_DL_SN"] = dlerror
# %time
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.63 µs

# %%
plt.subplot(121)

plt.xlabel("Redshifts")
plt.ylabel("Distance Modulus")
plt.title("Pantheon sample")
plt.errorbar(sort_data_SN.Z_SN,sort_data_SN.DMdata_SN,
             yerr=sort_data_SN.Error_DM_SN,fmt='.k', ecolor='gray',zorder=1,lw=2,
             label='error')
plt.scatter(sort_data_SN.Z_SN,sort_data_SN.DMdata_SN,color='black',linewidths=0.01,
            label='DM from SN data')
plt.plot(sort_data_SN.Z_SN,sort_data_SN.DMth_SN,'--r',lw=1.8, label='DM from VCG')

plt.legend(loc='lower right')

plt.subplot(122)
# plt.figure(figsize=(6, 6))
plt.errorbar(sort_data_SN.Z_SN,sort_data_SN.dLdata_SN,yerr=sort_data_SN.Error_DL_SN,
             fmt='.k',ecolor='gray', zorder=1,lw=2, label='error')
plt.plot(sort_data_SN.Z_SN,sort_data_SN.dLth_SN,'--r', label='LD from model',
         lw=1.8)
plt.scatter(sort_data_SN.Z_SN,sort_data_SN.dLdata_SN,color='black',
            linewidths=0.01,label='LD from SN data')
plt.xlabel("Redshifts")
plt.ylabel("Luminosity Distance (Mpc)")
plt.title("Pantheon sample")
plt.legend(loc='lower right')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=1.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.savefig("Pantheon_DM_DLvsz.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
sort_data_SN.head()
# Out:
#       Z_SN   App_Mag  Error_App_Mag  DMdata_SN  Error_DM_SN    DMth_SN  \
# 0  0.01012  13.90745        0.19825   33.25745      0.19825  33.208753
# 1  0.01038  14.04960        0.20480   33.39960      0.20480  33.264259
# 2  0.01043  13.92480        0.20035   33.27480      0.20035  33.274775
# 3  0.01082  14.00860        0.18445   33.35860      0.18445  33.355122
# 4  0.01209  13.97910        0.19140   33.32910      0.19140  33.598173
#
#      dLth_SN  dLdata_SN  Error_DL_SN
# 0  43.827893  44.821873     4.284742
# 1  44.962636  47.854193     4.733001
# 2  45.180906  45.181433     4.367009
# 3  46.883964  46.959125     4.163129
# 4  52.436615  46.325488     4.268627

# %% [markdown]
# # Chi_square test considering only Pantheon SN data points

# %%
H0
# Out:
# 69.8

# %%
chi_sq = []
collection=[]
col=[]
dlth_SN, dmth_SN, chi_sq= (np.zeros(len(z)), np.zeros(len(z)), np.zeros(len(z)))
a=0
b=0
h=0.698
c=3*10**5 
for omega_m in np.linspace(0.01,0.25,40): 
    for n in np.linspace(-1,3,40):
        for redshift in sort_data_SN.Z_SN:
            g = quad(int_func,0,redshift)
            dl1=(1+redshift)*g[0]
            dlth_SN[b]+=dl1
#             xx=(H0*dl1)/((3*10**8)*h) 
            dmth_SN[a]+=5.0 * np.log10(dl1) - 5 * np.log10(h) + 42.38 #or =5log(xx,10)+42.38
            a+=1
            b+=1
            sort_data_SN["DMchi"]=dmth_SN
        a=0
        b=0
        C2=0
        C1=0
        for i in sort_data_SN.Error_DM_SN:
            C2+=1/i**2
        sort_data_SN["dC1"]=(sort_data_SN["DMchi"]-sort_data_SN["DMdata_SN"])/(sort_data_SN["Error_DM_SN"]**2)
        for i in sort_data_SN["dC1"]:
            C1+=i
        del sort_data_SN["dC1"]
        chi_sq_part1 = 0
        sort_data_SN["Part1"]=((sort_data_SN["DMchi"]-sort_data_SN["DMdata_SN"])/sort_data_SN["Error_DM_SN"])**2
        for i in sort_data_SN.Part1:
            chi_sq_part1+=i
        del sort_data_SN["Part1"]
        chi_sq = chi_sq_part1+(C1/C2)*(C1+(2*np.log(10)/5))-(2*log(h))
        col.append(chi_sq)
        np_array=np.asarray(col)
        collection.append([chi_sq,omega_m,n])
        dlth_SN = np.zeros(len(z))
        dmth_SN = np.zeros(len(z))
        del sort_data_SN["DMchi"]

print(len(collection))
sigma1=[]
sigma2=[]
for i in collection:
    if i[0]==min(col):
        print("Minimum Chi sq value is",i,"\n")
        minimum=i
for i in collection: #https://ned.ipac.caltech.edu/level5/Wall2/Wal3_4.html
    if i[0]<=min(col) + 2.3: #for significance of 0.68, chi sq value inc by 2.30 from minimum
        sigma1.append(i)
omega_=[row[1] for row in sigma1]
n_=[row[2] for row in sigma1]
omegalowersigma1=np.max(minimum[1]-np.array(omega_))
omegauppersigma1=np.max(np.array(omega_)-minimum[1])
nlowersigma1=np.max(minimum[2]-np.array(n_))
nuppersigma1=np.max(np.array(n_)-minimum[2])
   
for i in collection:
    if i[0]<=min(col) + 4.61:
        #for significance of 0.96, chi sq value inc by 4.61 from minimum
        sigma2.append(i)
omega_=[row[1] for row in sigma2]
n_=[row[2] for row in sigma2]
omegalowersigma2=np.max(minimum[1]-np.array(omega_))
omegauppersigma2=np.max(np.array(omega_)-minimum[1])
nlowersigma2=np.max(minimum[2]-np.array(n_))
nuppersigma2=np.max(np.array(n_)-minimum[2])

print("1 sigma + Error in omega", omegauppersigma1)
print("1 sigma - Error in omega", omegalowersigma1)
print("1 sigma + Error in n", nuppersigma1)
print("1 sigma - Error in n", nlowersigma1)
print("2 sigma + Error in omega", omegauppersigma2)
print("2 sigma - Error in omega", omegalowersigma2)
print("2 sigma + Error in n", nuppersigma2)
print("2 sigma - Error in n", nlowersigma2)

# %time
# Out:
# 1600
# Minimum Chi sq value is [1037.050053798585, 0.1146153846153846, 1.2564102564102564]
#
# 1 sigma + Error in omega 0.024615384615384636
# 1 sigma - Error in omega 0.02461538461538461
# 1 sigma + Error in n 0.2051282051282053
# 1 sigma - Error in n 0.3076923076923077
# 2 sigma + Error in omega 0.04307692307692308
# 2 sigma - Error in omega 0.03692307692307692
# 2 sigma + Error in n 0.41025641025641013
# 2 sigma - Error in n 0.5128205128205128
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.11 µs

# %%
#plt.style.use('seaborn-white')
n= np.linspace(0.5,2.0,40)
omega_m =np.linspace(0.01,0.175,40)
np_array=np.asarray(col)
t1=np_array.reshape(40,40)
#fig,ax=plt.subplots(1,1)
levels = np.array([min(col)+2.3, min(col)+4.61, min(col)+9.21])
#https://ned.ipac.caltech.edu/level5/Wall2/Wal3_4.html
contours =plt.contourf(n,omega_m, t1,levels=levels, extend='min',cmap = 'gist_gray')
plt.xlabel('n')
plt.ylabel('$\Omega_m$')
plt.title("$\chi^2$ contours using Pantheon sample \n")
plt.xlim(1,1.7)
plt.ylim(0.01,0.14)
#plt.clabel(contours, inline=True, fontsize=8, colors='b')
#cp.set_clim(vmin=560,vmax=600)
#cb_ax = fig.add_axes([0.83, 0.1, 0.02, 0.8])
plt.colorbar() # Add a colorbar to a plot
#plt.clim(0, 150) 
plt.savefig("chisqPantheon.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
# !wget http://supernova.lbl.gov/Union/figures/SCPUnion2.1_mu_vs_z.txt
d = np.genfromtxt('SCPUnion2.1_mu_vs_z.txt')
z1 = d.T[1]
mu1 = d.T[2]
errmu= d.T[3]
dlabel = 'SCP_2.1'
label = {"Z_SN":z1,"DMdata_SN":mu1,"Error_DM_SN":errmu}
data_SCP=pd.DataFrame(label)
#print(data_SN)
sort_data_SCP=data_SCP.sort_values(by=['Z_SN'],ignore_index=True)
# !wget https://supernova.lbl.gov/Union/figures/SCPUnion2.1_covmat_sys.txt
cov_mat = np.genfromtxt('SCPUnion2.1_covmat_sys.txt')

# %%
z=sort_data_SCP.Z_SN
mu=sort_data_SCP.DMdata_SN
errdm=dm=sort_data_SCP.Error_DM_SN
def int_func(redshift):
      return 1/((pow((1+redshift),2)*(omega_r0+(omega_b0/(1+redshift))+((1-omega_b0-omega_r0)*((omega_m*(1+redshift)**6)+(1-omega_m)*(1+redshift)**n)**(0.5)/(1+redshift)**(4)))**(0.5)))

# %%
# Chi_square test considering only SN data points
chi_sq = []
collection=[]
col1=[]
dlth_SN= np.zeros(len(z))
dmth_SN= np.zeros(len(z))
chi_sq=np.zeros(len(z))
a=0
b=0
h=0.698
for omega_m in np.linspace(0.01,0.25,40): 
  for n in np.linspace(-0.5,2.2,40):
    for redshift in data_SCP.Z_SN:
      g = quad(int_func,0,redshift)
      dl1=(1+redshift)*g[0]*(3*10**8/H0)
      dlth_SN[b]+=dl1
      xx=(H0*dl1)/((3*10**8)*h) 
      dmth_SN[a]+=5.*log(xx,10)+42.38 
      a+=1
      b+=1
      data_SCP["DMchi"]=dmth_SN
    a=0
    b=0
    C2=0
    C1=0
    for i in data_SCP.Error_DM_SN:
      C2+=1/np.power(i,2)
    data_SCP["dC1"]=(data_SCP["DMchi"]-data_SCP["DMdata_SN"])/(data_SCP["Error_DM_SN"]**2)
    for i in data_SCP["dC1"]:
      C1+=i
    del data_SCP["dC1"]
    chi_sq_part1 = 0
    data_SCP["Part1"]=((data_SCP["DMchi"]-data_SCP["DMdata_SN"])/data_SCP["Error_DM_SN"])**2
    for i in data_SCP.Part1:
      chi_sq_part1+=i
    del data_SCP["Part1"]
    chi_sq = chi_sq_part1+(C1/C2)*(C1+(2*log(10,10)/5))-(2*log(0.698))
    col1.append(chi_sq)
    np_array=np.asarray(col)
    collection.append([chi_sq,omega_m,n])
    dlth_SN = np.zeros(len(z))
    dmth_SN = np.zeros(len(z))
    del data_SCP["DMchi"]

print(len(collection))
for i in collection:
  if i[0]==min(col1):
    print(i)
print("1sigma")    
for i in collection:
  if i[0]<=min(col1) + 2.3:
    print(i)
print("2 sigma")    
for i in collection:
  if i[0]<=min(col1) + 4.61:
    print(i)
# %time
# Out:
# 1600
# [563.0437134184856, 0.09615384615384615, 1.3]
# 1sigma
# [564.9212849578468, 0.05307692307692308, 1.7153846153846155]
# [565.2272668309763, 0.05307692307692308, 1.784615384615385]
# [564.4834342552632, 0.05923076923076923, 1.646153846153846]
# [564.6379119677414, 0.05923076923076923, 1.7153846153846155]
# [565.1006228533066, 0.06538461538461539, 1.5076923076923077]
# [564.1216142040248, 0.06538461538461539, 1.576923076923077]
# [564.1550771660833, 0.06538461538461539, 1.646153846153846]
# [565.215060309788, 0.06538461538461539, 1.7153846153846155]
# [564.850285562775, 0.07153846153846154, 1.4384615384615387]
# [563.8281624972527, 0.07153846153846154, 1.5076923076923077]
# [563.7683536042807, 0.07153846153846154, 1.576923076923077]
# [564.6850215532908, 0.07153846153846154, 1.646153846153846]
# [564.6400190121955, 0.07769230769230769, 1.3692307692307693]
# [563.5973267273023, 0.07769230769230769, 1.4384615384615387]
# [563.4694281014457, 0.07769230769230769, 1.5076923076923077]
# [564.2704922320867, 0.07769230769230769, 1.576923076923077]
# [566.6009081599989, 0.13923076923076924, 0.953846153846154]
# [567.4761107010604, 0.1453846153846154, 0.46923076923076934]
# [566.1220189699833, 0.1453846153846154, 0.5384615384615385]
# [565.2791066353201, 0.1453846153846154, 0.6076923076923078]
# [564.9580770521767, 0.1453846153846154, 0.676923076923077]
# [565.1697924321923, 0.1453846153846154, 0.7461538461538462]
# [565.9252728274046, 0.1453846153846154, 0.8153846153846154]
# [567.235694849384, 0.1453846153846154, 0.8846153846153846]
# [567.608966474177, 0.15153846153846154, 0.4]
# [566.4173922005554, 0.15153846153846154, 0.46923076923076934]
# [565.7131554370187, 0.15153846153846154, 0.5384615384615385]
# [565.5065778307458, 0.15153846153846154, 0.6076923076923078]
# [565.808141393824, 0.15153846153846154, 0.676923076923077]
# [566.628488001218, 0.15153846153846154, 0.7461538461538462]
# [566.7998137166387, 0.1576923076923077, 0.4]
# [566.2364731847924, 0.1576923076923077, 0.46923076923076934]
# [566.147874180907, 0.1576923076923077, 0.5384615384615385]
# [566.5441220949964, 0.1576923076923077, 0.6076923076923078]
# [567.4354831032372, 0.1576923076923077, 0.676923076923077]
# [567.2772885717811, 0.16384615384615386, 0.3307692307692308]
# [566.8563740252504, 0.16384615384615386, 0.4]
# [566.8885147552696, 0.16384615384615386, 0.46923076923076934]
# [567.3834448722552, 0.16384615384615386, 0.5384615384615385]
# [567.5803253473324, 0.17, 0.3307692307692308]
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 8.58 µs

# %%
n= np.linspace(-0.5,2.2,40)
omega_m =np.linspace(0.01,0.25,40)
np_array1=np.asarray(col1)
np_array=np.asarray(col)
t1=np_array.reshape(40,40)
t2=np_array1.reshape(40,40)
#fig,ax=plt.subplots(1,1)
levels =  np.array([min(col)+2.3, min(col)+4.61, min(col)+9.21])
levels1 =  np.array([min(col1)+2.3, min(col1)+4.61, min(col1)+9.21])

plt.contourf(n,omega_m, t2,levels=levels1, extend='min',cmap='pink')
clb1=plt.colorbar()
plt.contourf(n,omega_m, t1,levels=levels, extend='min',cmap = 'gist_gray')
plt.xlabel('n')
plt.ylabel('$\Omega_m$')
plt.title("$\chi^2$ contours using SCP Union 2.1 \n and Pantheon sample\n")
# plt.title("$\chi^2$ Contours from GW measurement")
plt.ylim(0.01,0.21)
clb2=plt.colorbar() # Add a colorbar to a plot
clb2.ax.set_title('Pantheon', rotation=270)
clb1.ax.set_title('SCP Union 2.1', rotation=270)
plt.savefig("chisqPantheonSCP.pdf", format="pdf", bbox_inches="tight")
plt.show()
#plt.clim(0, 150)

# %%
name=np.array(['GW190521','GW190706_222641','GW190413_134308','GW190514_065416','GW190719_215514','GW190521',"GW190909_114149","GW190413_052954",'GW190803_022701','GW190731_140936','GW190727_060333','GW190620_030421','GW190421_213856','GW170729','GW190602_175927','GW190527_092055','GW190519_153544','GW190424_180648','GW190929_012149','GW190828_063405','GW190701_203306','GW190513_205428','GW170823','GW190517_055101','GW190915_235702','GW190828_065509','GW190408_181802','GW190910_112807','GW190512_180714','GW190503_185404','GW190521_074359','GW170818','GW151012','GW170809','GW170104','GW190728_064510','GW190708_232457','GW190630_185205','GW190720_000836','GW190707_093326','GW190930_133541','GW190412','GW190924_021846','GW170814','GW151226','GW150914','GW190426_152155','GW200115_042309','GW170608','GW200105_162426','GW190814','GW190425','GW170817'])
full_DL_GW=np.array([[5300.0,2400,-2600],[4420.0,2590,-1930],[4450,2480,-2120],[4130.0,2650,-2170],[3940.0,2590,-2000],[3920.0,2190,-1950],[3770.0,3270,-2220],[3550.0,2270,-1660],[3270.0,1950,-1580],[3300.0,2390,-1720],[3300.0,1540,-1500],[2810.0,1680,-1310],[2880.0,1370,-1380],[2840.0,1400,-1360],[2690.0,1790,-1120],[2490.0,2480,-1240],[2530.0,1830,-920],[2200.0,1580,-1160],[2130.0,3650,-1050],[2130.0,660,-930],[2060.0,760,-730],[2060.0,880,-800],[1940.0,970,-900],[1860.0,1620,-840],[1620.0,710,-610],[1600.0,620,-600],[1550.0,400,-600],[1460.0,1030,-580],[1430.0,550,-550],[1450.0,690,-630],[1240.0,400,-570],[1060.0,420,-380],[1080.0,550,-490],[1030.0,320,-390],[990.0,440,-430],[870.0,260,-370],[880.0,330,-390],[890.0,560,-370],[790.0,690,-320],[770.0,380,-370],[760.0,360,-320],[740.0,140,-170],[570.0,220,-220],[600.0,150,-220],[450.0,180,-190],[440.0,150,-170],[370.0,180,-160],[300.0,150,-100],[320.0,120,-110],[280.0,110,-110],[241.0,41,-45],[159.0,69,-72],[40.0,7,-15]])
full_Z_GW=np.array([[0.82,0.28,-0.34],[0.71,0.32,-0.27],[0.71,0.31,-0.30],[0.67,0.33,-0.31],[0.64,0.33,-0.29],[0.64,0.28,-0.28],[0.62,0.41,-0.33],[0.59,0.29,-0.24],[0.55,0.26,-0.24],[0.55,0.31,-0.26],[0.55,0.21,-0.22],[0.49,0.23,-0.20],[0.49,0.19,-0.21],[0.49,0.19,-0.21],[0.47,0.25,-0.17],[0.44,0.34,-0.20],[0.44,0.25,-0.14],[0.39,0.23,-0.19],[0.38,0.49,-0.17],[0.38,0.10,-0.15],[0.37,0.11,-0.12],[0.37,0.13,-0.13],[0.35,0.15,-0.15],[0.34,0.24,-0.14],[0.3,0.11,-0.10],[0.3,0.10,-0.10],[0.29,0.06,-0.10],[0.28,0.16,-0.10],[0.27,0.09,-0.10],[0.27,0.11,-0.11],[0.24,0.07,-0.10],[0.21,0.07,-0.07],[0.21,0.09,-0.09],[0.2,0.05,-0.07],[0.2,0.08,-0.08],[0.18,0.05,-0.07],[0.18,0.06,-0.07],[0.18,0.10,-0.07],[0.16,0.12,-0.06],[0.16,0.07,-0.07],[0.15,0.06,-0.06],[0.15,0.03,-0.03],[0.12,0.04,-0.04],[0.12,0.03,-0.04],[0.09,0.04,-0.04],[0.09,0.03,-0.03],[0.08,0.04,-0.03],[0.07,0.03,-0.02],[0.07,0.02,-0.02],[0.06,0.02,-0.02],[0.053,0.009,-0.010],[0.04,0.01,-0.02],[0.01,0.00,-0.00]])
# Number of events
a=name.size

#Defining arrays
dldata_GW=np.zeros(a)
dlUP=np.zeros(a)
dlLOW=np.zeros(a)
dlTOP=np.zeros(a)
dlBOTTOM=np.zeros(a)
dmtop=np.zeros(a)
dmbottom=np.zeros(a)
Z_GW=np.zeros(a)
dmth_GW=np.zeros(a)
dmdata_GW=np.zeros(a)
dlth_GW = np.zeros(a)
dmtoperr=np.zeros(a)
dmbottomerr=np.zeros(a)
#defining variables for index of the above arrays
b=c=d=e=f=h=k=l=m=x=y=p=q=r=s=0
#extracting redshifts and DL from the full data
for i in full_Z_GW:
  Z_GW[e]+=i[0]
  e+=1
for i in full_DL_GW:
  dldata_GW[b]+=i[0]
  b+=1
#Upper and Lower limit of DL from data
for i in full_DL_GW:
  dlUP[c]+=i[0]+i[1]
  c+=1
for i in full_DL_GW:
  dlLOW[d]+=i[0]+i[2]
  d+=1
# Calculating upper and lower limit of Distance modulus from DL limits calculated above
for i in dlUP:
  dmtop[f]+=5*log(i,10)+25
  f+=1
for i in dlLOW:
  dmbottom[k]+=5*log(i,10)+25
  k+=1
#Calculating DM from DL given in data
for i in dldata_GW:
  dmdata_GW[h]+=5*log(i,10)+25
  h+=1
#Calculating differences in DL from its limits
for (i,j) in zip(dldata_GW,dlUP):
  dlTOP[x]+=j-i
  x+=1
for (i,j) in zip(dldata_GW,dlLOW):
  dlBOTTOM[y]=i-j
  y+=1
#upper and lower differences for errors
for (i,j) in zip(dmdata_GW,dmtop):
  dmtoperr[r]+=j-i
  r+=1
for (i,j) in zip(dmdata_GW,dmbottom):
  dmbottomerr[s]+=i-j
  s+=1
omega_m=.09
n=1.4545
# Calculating theoretical value of DL and DM from the model VCG
for redshift in Z_GW:
  g=quad(int_func,0,redshift)
  dlth_GW[l]+=(1+redshift)*g[0]*(300000/(H0)) 
  l+=1
for i in dlth_GW:
  dmth_GW[m]+=5*log(i,10)+25
  m+=1
# DL-h1 < DL < DL+h2,if h1<h2, take error to be h1 or vice versa
#new_error=np.zeros(a)
#for (i,j) in zip(dlTOP,dlBOTTOM):
 # if i<j:
#    new_error[p]+=i
#    p+=1
#  elif j<i:
#    new_error[q]+=j
 #   q+=1

new_error=np.zeros(a)
for i in range (a):
  if dmtoperr[i]>dmbottomerr[i]:
    new_error[p]+=dmtoperr[i]
  elif dmtoperr[i]<dmbottomerr[i]:
    new_error[p]+=dmbottomerr[i]
  else:
    new_error[p]+=dmtoperr[i]
  p+=1  
#for (i,j) in zip(dmtoperr,dmbottomerr):
#  if i<j:
 #  new_error[p]+=i
  # p+=1
#  elif j<i:
 #  new_error[q]+=j
  # q+=1

label1 = {"Event_Name":name,"Z_GW":Z_GW,"dLdata_GW":dldata_GW,"DMdata_GW": dmdata_GW,"dLth_GW":dlth_GW, "DMth_GW": dmth_GW,"DL_Uplimit": dlUP, "DL_Lowlimit": dlLOW,"DL_UP_Error":dlTOP,"DL_LOW_Error":dlBOTTOM,  "DM_UpError": dmtoperr, "DM_LowError":dmbottomerr, "Error_DM_GW":new_error}
data_GW=pd.DataFrame(label1)
#data_GW.to_excel(excel_writer = "/root/Github_Repos/VCG_GW/GWTColdGW.xlsx")

# %%
data_GWTC3 = pd.read_excel ('/media/ash/1tb/github/HubbleConstant-ConstraintsForVCG/oldGW.xlsx')
data_GWTC3.index= np.arange(53,88)

# %%
mucollect=[data_GW.Z_GW,data_GWTC3.redshift]
finalredshift = pd.concat(mucollect)

namecollect=[data_GW.Event_Name,data_GWTC3.Event_Name_GWTC3]
finalevents = pd.concat(namecollect)

dlcollect=[data_GW.dLdata_GW,data_GWTC3.luminosity_distance]
finaldl = pd.concat(dlcollect)

dlupcollect=[data_GW.DL_Uplimit,data_GWTC3.luminosity_distance_upper]
finaldlup = pd.concat(dlupcollect)

dllowcollect=[data_GW.DL_Lowlimit,data_GWTC3.luminosity_distance_lower]
finaldllow = pd.concat(dllowcollect)

a=finalevents.size

#Defining arrays
dlTOP=np.zeros(a)
dlBOTTOM=np.zeros(a)
dmtop=np.zeros(a)
dmbottom=np.zeros(a)
dmth3_GW=np.zeros(a)
dmdata_GW=np.zeros(a)
dlth3_GW = np.zeros(a)
dmtoperr=np.zeros(a)
dmbottomerr=np.zeros(a)
#defining variables for index of the above arrays
f=h=k=l=m=x=y=p=q=r=s=0

# Calculating upper and lower limit of Distance modulus from DL limits calculated above
for i in finaldlup:
  dmtop[f]+=5*log(i,10)+25
  f+=1
for i in finaldllow:
  dmbottom[k]+=5*log(i,10)+25
  k+=1
#Calculating DM from DL given in data
for i in finaldl:
  dmdata_GW[h]+=5*log(i,10)+25
  h+=1
#upper and lower differences for errors
for (i,j) in zip(dmdata_GW,dmtop):
  dmtoperr[r]+=j-i
  r+=1
for (i,j) in zip(dmdata_GW,dmbottom):
  dmbottomerr[s]+=i-j
  s+=1
omega_m=.09
n=1.4545

# Calculating theoretical value of DL and DM from the model VCG
for i in finalredshift:
  g=quad(int_func,0,i)
  dlth3_GW[l]+=(1+i)*g[0]*(300000/(H0))  
  l+=1
for i in dlth3_GW:
  dmth3_GW[m]+=5*log(i,10)+25
  m+=1
    
new_error=np.zeros(a)
for i in range (a):
  if dmtoperr[i]<dmbottomerr[i]:
    new_error[p]+=dmtoperr[i]
  elif dmtoperr[i]>dmbottomerr[i]:
    new_error[p]+=dmbottomerr[i]
  else:
    new_error[p]+=dmtoperr[i]
  p+=1   
label2 = {"Fin_Event_Name":finalevents,"Fin_Z_GW":finalredshift,"Fin_dLdata_GW":finaldl,"Fin_DMdata_GW": dmdata_GW,"Fin_dLth_GW":dlth3_GW, "Fin_DMth_GW": dmth3_GW,"Fin_DL_UpError": finaldlup, "Fin_DL_LowError": finaldllow,  "DM_UpError": dmtoperr, "DM_LowError":dmbottomerr, "Error_DM_GW":new_error}
Fin_data_GW=pd.DataFrame(label2)

print(dmtoperr<0)
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False]

# %%
namecollect=[data_GW.Event_Name,data_GWTC3.Event_Name_GWTC3]
finalevents = pd.concat(namecollect)

# %%
sort_data_GW=Fin_data_GW.sort_values(by=['Fin_Z_GW'])

# %%
# Chi_square test considering only GW data points
chi_sq = []
collection=[]
nconf=np.zeros(15876)
omegconf=np.zeros(15876)
col2=[]
dlth_GW= np.zeros(88)
dmth_GW= np.zeros(88)
chi_sq=np.zeros(88)
a=0
b=0
c=0
d=0
h=0.698
H0=69.8

for omega_m in np.linspace(0.01,0.4,40): 
  for n in np.linspace(-2,3,40):
    for redshift in Fin_data_GW.Fin_Z_GW:
      g = quad(int_func,0,redshift)
      dl1=(1+redshift)*g[0]*(3*10**8/H0)
      dlth_GW[b]+=dl1
      xx=(H0*dl1)/((3*10**8)*h) 
      dmth_GW[a]+=5.*log(xx,10)+42.38
      a+=1
      b+=1
      Fin_data_GW["DMchi"]=dmth_GW
    a=0
    b=0
    C2=0
    C1=0
    for i in new_error:
      C2+=1/np.power(i,2)
    Fin_data_GW["dC1"]=(Fin_data_GW["DMchi"]-Fin_data_GW["Fin_DMdata_GW"])/(new_error**2)
    for i in Fin_data_GW["dC1"]:
      C1+=i
    del Fin_data_GW["dC1"]
    chi_sq_part1 = 0
    Fin_data_GW["Part1"]=((Fin_data_GW["DMchi"]-Fin_data_GW["Fin_DMdata_GW"])/new_error)**2
    for i in Fin_data_GW.Part1:
      chi_sq_part1+=i
    del Fin_data_GW["Part1"]
    chi_sq = chi_sq_part1+(C1/C2)*(C1+(2*log(10)/5))-(2*log(h))
    col2.append(chi_sq)
    collection.append([chi_sq,omega_m,n])
    c+=1
    d+=1
    np_array=np.asarray(col2)
    dlth_GW = np.zeros(88)
    dmth_GW = np.zeros(88)
    del Fin_data_GW["DMchi"]
     
print(len(collection))
for i in collection:
      if i[0]==min(col2):
            print(i)  
# for i in collection:
#     if i[0]<=min(col1) + 2.3:
#         if i[0]>= min(col1):
#             print(i)

# %time
# Out:
# 1600
# [1.419682331686813, 0.22, -2.0]
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 12.6 µs

# %%
n= np.linspace(-2,3,40)
omega_m =np.linspace(0.01,0.4,40)
np_array2=np.asarray(col2)
np_array1=np.asarray(col1)
np_array=np.asarray(col)
t1=np_array.reshape(40,40)
t2=np_array1.reshape(40,40)
t3=np_array2.reshape(40,40)
#fig,ax=plt.subplots(1,1)
levels  =  np.array([min(col)+2.3, min(col)+4.61, min(col)+9.21])
levels1 =  np.array([min(col1)+2.3, min(col1)+4.61, min(col1)+9.21])
levels2 =  np.array([min(col2)+2.3, min(col2)+4.61, min(col2)+9.21])
plt.contourf(n,omega_m, t3,levels=levels2, extend='min',cmap = 'summer')
clb1=plt.colorbar(pad=0.06)
plt.contourf(n,omega_m, t2,levels=levels1, extend='min',cmap = 'pink')
clb2=plt.colorbar(pad=0.09)
plt.contourf(n,omega_m, t1,levels=levels, extend='min',cmap='gist_gray')
clb3=plt.colorbar()

plt.xlabel('n')
plt.ylabel('$\Omega_m$')
plt.title("$\chi^2$ contours from SCP Union 2.1,\n Pantheon sample and GWTC-3\n")
#figure(figsize=(4, 12))
#plt.clabel(contours, inline=True, fontsize=8, colors='b')
#cp.set_clim(vmin=560,vmax=600)
#cb_ax = fig.add_axes([0.83, 0.1, 0.02, 0.8])
# clb1.ax.get_yaxis().labelpad = 15
clb1.ax.set_title('GWTC-3', rotation=270)
# clb2.ax.get_yaxis().labelpad = 60
clb2.ax.set_title('SCP Union 2.1', rotation=270)
# clb2.ax.get_yaxis().labelpad = 15
clb3.ax.set_title('Pantheon', rotation=270)
plt.savefig("chisqPantheonSCPGW.pdf", format="pdf", bbox_inches="tight")
plt.show()
#plt.clim(0, 150)
